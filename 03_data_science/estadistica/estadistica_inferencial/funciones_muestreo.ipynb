# %%
import pandas as pd
import numpy as np
import random
import io

# %% [markdown]
# ### Leemos la base de datos a trabajar en nuestra ruta de origen

# %%
econdata = pd.read_csv("econdata.csv")
econdata.head()
# Out:
#    id                  geo_point_2d  \
# 0   0   19.424781053,-99.1327537959
# 1   1  19.4346139576,-99.1413808393
# 2   2  19.4340695945,-99.1306348409
# 3   3      19.42489472,-99.12073393
# 4   4      19.42358238,-99.12451093
#
#                                            geo_shape   clave_cat  \
# 0  {"type": "Polygon", "coordinates": [[[-99.1332...  307_130_11
# 1  {"type": "MultiPoint", "coordinates": [[-99.14...  002_008_01
# 2  {"type": "MultiPoint", "coordinates": [[-99.13...  006_002_12
# 3  {"type": "MultiPoint", "coordinates": [[-99.12...  323_102_06
# 4  {"type": "MultiPoint", "coordinates": [[-99.12...  323_115_12
#
#             delegacion perimetro     tipo  \
# 0           Cuauhtémoc         B  Mercado
# 1            Cuautémoc         A    Museo
# 2            Cuautémoc         A    Museo
# 3  Venustiano Carranza         B    Hotel
# 4  Venustiano Carranza         B    Hotel
#
#                                               nom_id
# 0                                        Pino Suárez
# 1  Museo Nacional de Arquitectura Palacio de Bell...
# 2                                       Santa Teresa
# 3                                           Balbuena
# 4                                               real

# %% [markdown]
# ### Funciones de muestreo

# %% [markdown]
# #### 1) Muestreo aleatorio simple:

# %%
aleat_8 = econdata.sample(n=8)
aleat_8
# Out:
#       id                  geo_point_2d  \
# 111  111  19.4430614318,-99.1353793874
# 107  107  19.4248237343,-99.1311696681
# 54    54  19.4263645964,-99.1399088724
# 228  228  19.4406567734,-99.1394531646
# 32    32  19.4369607249,-99.1354098031
# 115  115  19.4336966991,-99.1237253904
# 169  169  19.4365391003,-99.1335799561
# 121  121  19.4303083246,-99.1405735286
#
#                                              geo_shape   clave_cat  \
# 111  {"type": "MultiPoint", "coordinates": [[-99.13...  004_107_02
# 107  {"type": "Polygon", "coordinates": [[[-99.1313...  307_128_04
# 54   {"type": "MultiPoint", "coordinates": [[-99.13...  001_076_12
# 228  {"type": "MultiPoint", "coordinates": [[-99.13...  004_069_01
# 32   {"type": "MultiPoint", "coordinates": [[-99.13...  004_101_20
# 115  {"type": "MultiPoint", "coordinates": [[-99.12...  323_010_09
# 169  {"type": "MultiPoint", "coordinates": [[-99.13...  004_093_16
# 121  {"type": "MultiPoint", "coordinates": [[-99.14...  001_043_15
#
#               delegacion perimetro     tipo                  nom_id
# 111            Cuautémoc         B    Hotel             Embajadores
# 107           Cuauhtémoc         B  Mercado               San Lucas
# 54             Cuautémoc         B    Hotel  Cadillac, S.A. DE C.V.
# 228            Cuautémoc         B    Museo        Tequila y Mescal
# 32             Cuautémoc         A    Hotel            Habana, S.A.
# 115  Venustiano Carranza         B    Hotel                   Antas
# 169            Cuautémoc         A    Hotel                  Azores
# 121            Cuautémoc         A    Hotel             El Salvador

# %%
prop_25 = econdata.sample(frac=0.25)
prop_25.head(10)
# Out:
#       id                  geo_point_2d  \
# 188  188  19.4281241134,-99.1460742157
# 195  195  19.4414840739,-99.1394736635
# 198  198   19.4265500891,-99.137772913
# 94    94  19.4338001466,-99.1463273233
# 66    66  19.4331350004,-99.1382989213
# 8      8   19.4343402009,-99.148212127
# 171  171  19.4263416792,-99.1296771488
# 70    70       19.43712772,-99.1378899
# 139  139  19.4331109726,-99.1250977437
# 106  106  19.4260404694,-99.1546283991
#
#                                              geo_shape   clave_cat  \
# 188  {"type": "MultiPoint", "coordinates": [[-99.14...  002_067_08
# 195  {"type": "MultiPoint", "coordinates": [[-99.13...  004_050_13
# 198  {"type": "MultiPoint", "coordinates": [[-99.13...  001_066_05
# 94   {"type": "MultiPoint", "coordinates": [[-99.14...  002_016_02
# 66   {"type": "MultiPoint", "coordinates": [[-99.13...  001_021_14
# 8    {"type": "MultiPoint", "coordinates": [[-99.14...  002_014_17
# 171  {"type": "MultiPoint", "coordinates": [[-99.12...  006_092_06
# 70   {"type": "MultiPoint", "coordinates": [[-99.13...  004_090_02
# 139  {"type": "MultiPoint", "coordinates": [[-99.12...  006_009_11
# 106  {"type": "Polygon", "coordinates": [[[-99.1550...  011_245_01
#
#      delegacion perimetro     tipo                nom_id
# 188   Cuautémoc         B    Hotel              Manolo 1
# 195   Cuautémoc         B    Hotel             Emperador
# 198   Cuautémoc         A    Hotel               Torreon
# 94    Cuautémoc         B    Museo          Arte Popular
# 66    Cuautémoc         A    Hotel               Coliseo
# 8     Cuautémoc         B    Hotel            Ambassador
# 171   Cuautémoc         A    Hotel            Las Cruces
# 70    Cuautémoc         A    Hotel              Congreso
# 139   Cuautémoc         A    Hotel  Continental Méxicano
# 106  Cuauhtémoc         B  Mercado                Juárez

# %% [markdown]
# ### Muestro sistematico

# %%
def systematic_sampling(econdata,step):
    indexes = np.arange(0, len(econdata), step = step)
    systematic_sample = econdata.iloc[indexes]
    return systematic_sample

systematic_sample = systematic_sampling(econdata, 3)
systematic_sample
# Out:
#       id                  geo_point_2d  \
# 0      0   19.424781053,-99.1327537959
# 3      3      19.42489472,-99.12073393
# 6      6      19.43553422,-99.12324801
# 9      9  19.4407152937,-99.1498060057
# 12    12      19.43990186,-99.14813347
# ..   ...                           ...
# 216  216  19.4247697438,-99.1249707246
# 219  219  19.4234096295,-99.1438351156
# 222  222   19.4397905042,-99.134628735
# 225  225      19.43094655,-99.12455418
# 228  228  19.4406567734,-99.1394531646
#
#                                              geo_shape   clave_cat  \
# 0    {"type": "Polygon", "coordinates": [[[-99.1332...  307_130_11
# 3    {"type": "MultiPoint", "coordinates": [[-99.12...  323_102_06
# 6    {"type": "MultiPoint", "coordinates": [[-99.12...  318_116_11
# 9    {"type": "MultiPoint", "coordinates": [[-99.14...  012_146_22
# 12   {"type": "MultiPoint", "coordinates": [[-99.14...  003_079_16
# ..                                                 ...         ...
# 216  {"type": "Polygon", "coordinates": [[[-99.1250...  323_118_37
# 219  {"type": "MultiPoint", "coordinates": [[-99.14...  002_118_03
# 222  {"type": "MultiPoint", "coordinates": [[-99.13...  004_063_10
# 225  {"type": "MultiPoint", "coordinates": [[-99.12...  323_027_04
# 228  {"type": "MultiPoint", "coordinates": [[-99.13...  004_069_01
#
#               delegacion perimetro     tipo                  nom_id
# 0             Cuauhtémoc         B  Mercado             Pino Suárez
# 3    Venustiano Carranza         B    Hotel                Balbuena
# 6    Venustiano Carranza         B    Hotel    San Antonio Tomatlan
# 9              Cuautémoc         B    Hotel                 Detroit
# 12             Cuautémoc         B    Hotel                  La Paz
# ..                   ...       ...      ...                     ...
# 216  Venustiano Carranza         B  Mercado  Lamininas de La Merced
# 219            Cuautémoc         B    Hotel          Prado Floresta
# 222            Cuautémoc         A    Hotel                  Ladero
# 225  Venustiano Carranza         B    Hotel           Gran Veracruz
# 228            Cuautémoc         B    Museo        Tequila y Mescal
#
# [77 rows x 8 columns]

# %% [markdown]
# ### 3) Muestreo estratificado

# %%
econdata['estratificado'] = econdata['delegacion'] + "," + econdata["tipo"]
(econdata['estratificado'].value_counts() / len(econdata)).sort_values(ascending=False)
# Out:
# estratificado
# Cuautémoc,Hotel                0.643478
# Cuautémoc,Museo                0.156522
# Venustiano Carranza,Hotel      0.078261
# Cuauhtémoc,Mercado             0.073913
# Venustiano Carranza,Mercado    0.047826
# Name: count, dtype: float64

# %% [markdown]
# Nuestros datos dicen que la proporcion es la siguiente:
#
# 1) Hoteles en Cuahtémoc 0.5
#
# 2) Museos en Cuahtémoc 0.2
#
# 3) Hoteles en Venustiana Carranza 0.1
#
# 4) Mercados en Venusuano Carranza 0.1

# %%
def data_estratificada(ecodata, nombres_columnas_estrat, valores_estrat, prop_estrat, random_state = None):
    df_estrat = pd.DataFrame(columns= ecodata.columns)

    pos= -1
    for i in range(len(valores_estrat)):
        pos += 1
        if pos == len(valores_estrat) -1:
            ratio_len = len(ecodata) - len(df_estrat)
        else:
            ratio_len = int(len(ecodata) * prop_estrat[i])

        df_filtrado = ecodata[ecodata[nombres_columnas_estrat] == valores_estrat[i]]
        df_temp = df_filtrado.sample(replace = True, n= ratio_len, random_state=random_state)
    return df_temp

# %%
valores_estrat = ['Cuautémoc,Hotel', 'Cuautémoc,Museo', 'Venustiano Carranza,Hotel', 'Cuauhtémoc,Mercado', 'Venustiano Carranza,Mercado']
prop_esrtat = [0.5, 0.2, 0.1, 0.1, 0.1]
df_estrat = data_estratificada(econdata, 'estratificado', valores_estrat, prop_esrtat, random_state= 42)
df_estrat
# Out:
#       id                  geo_point_2d  \
# 157  157  19.4272935771,-99.1227492994
# 77    77  19.4254536359,-99.1226996335
# 216  216  19.4247697438,-99.1249707246
# 163  163  19.4265454033,-99.1224859032
# 128  128  19.4270781084,-99.1210175514
# ..   ...                           ...
# 77    77  19.4254536359,-99.1226996335
# 216  216  19.4247697438,-99.1249707246
# 77    77  19.4254536359,-99.1226996335
# 49    49  19.4264953358,-99.1248854383
# 204  204  19.4260286762,-99.1249971994
#
#                                              geo_shape        clave_cat  \
# 157  {"type": "Polygon", "coordinates": [[[-99.1230...       323_063_08
# 77   {"type": "Polygon", "coordinates": [[[-99.1233...       323_101_01
# 216  {"type": "Polygon", "coordinates": [[[-99.1250...       323_118_37
# 163  {"type": "Polygon", "coordinates": [[[-99.1231...       323_063_05
# 128  {"type": "Polygon", "coordinates": [[[-99.1214...  323_061_04(123)
# ..                                                 ...              ...
# 77   {"type": "Polygon", "coordinates": [[[-99.1233...       323_101_01
# 216  {"type": "Polygon", "coordinates": [[[-99.1250...       323_118_37
# 77   {"type": "Polygon", "coordinates": [[[-99.1233...       323_101_01
# 49   {"type": "Polygon", "coordinates": [[[-99.1252...       323_139_01
# 204  {"type": "Polygon", "coordinates": [[[-99.1253...       323_138_01
#
#               delegacion perimetro     tipo                  nom_id  \
# 157  Venustiano Carranza         B  Mercado          Merced Comidas
# 77   Venustiano Carranza         B  Mercado    La Merced Nave Menor
# 216  Venustiano Carranza         B  Mercado  Lamininas de La Merced
# 163  Venustiano Carranza         B  Mercado                     NaN
# 128  Venustiano Carranza         B  Mercado             San Ciprian
# ..                   ...       ...      ...                     ...
# 77   Venustiano Carranza         B  Mercado    La Merced Nave Menor
# 216  Venustiano Carranza         B  Mercado  Lamininas de La Merced
# 77   Venustiano Carranza         B  Mercado    La Merced Nave Menor
# 49   Venustiano Carranza         B  Mercado     Dulceria Don Goloso
# 204  Venustiano Carranza         B  Mercado                Florería
#
#                    estratificado
# 157  Venustiano Carranza,Mercado
# 77   Venustiano Carranza,Mercado
# 216  Venustiano Carranza,Mercado
# 163  Venustiano Carranza,Mercado
# 128  Venustiano Carranza,Mercado
# ..                           ...
# 77   Venustiano Carranza,Mercado
# 216  Venustiano Carranza,Mercado
# 77   Venustiano Carranza,Mercado
# 49   Venustiano Carranza,Mercado
# 204  Venustiano Carranza,Mercado
#
# [230 rows x 9 columns]
