# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
def f(x):
    return x**2

def df(f):
    h = 0.000001
    return (f(x+h)- f(x))/h

x = np.linspace(-10, 10, num = 1000)

y = f(x)

plt.plot(x, y, 'b')
plt.plot(x, df(f), 'r')
plt.grid()
