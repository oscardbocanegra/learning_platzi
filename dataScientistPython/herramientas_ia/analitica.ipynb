# %%
import pandas as pd

# %%
df = pd.read_csv('data/sales.csv')

# %%
df.columns
# Out:
# Index(['Row ID', 'Order ID', 'Order Date', 'Ship Date', 'Ship Mode',
#        'Customer ID', 'Customer Name', 'Segment', 'Country', 'City', 'State',
#        'Postal Code', 'Region', 'Product ID', 'Category', 'Sub-Category',
#        'Product Name', 'Sales'],
#       dtype='object')

# %%
import pandas as pd

# Asegurándote de que las fechas estén en formato datetime
df['Order Date'] = pd.to_datetime(df['Order Date'], format='mixed', dayfirst=True)
df['Ship Date'] = pd.to_datetime(df['Ship Date'], format='mixed', dayfirst=True)

# Creando una nueva columna que contiene la diferencia entre la fecha de envío y la fecha de pedido
df['Shipping Time'] = (df['Ship Date'] - df['Order Date']).dt.days

# Calculando el tiempo promedio de envío
average_shipping_time = df['Shipping Time'].mean()

print("El tiempo promedio de envío es de {} días.".format(average_shipping_time))
# Out:
# El tiempo promedio de envío es de 3.9611224489795918 días.

# %%
# %pip install matplotlib
import pandas as pd
import matplotlib.pyplot as plt

# Asumiendo que 'df' es tu DataFrame
grouped = df.groupby(['Region', 'Product Name'])['Sales'].sum().reset_index()

# Crea un DataFrame vacío para almacenar los 10 mejores productos por región
top10_products_per_region = pd.DataFrame()

# Para cada región, selecciona los 10 productos más vendidos
for region in grouped['Region'].unique():
    top_products = grouped[grouped['Region'] == region].nlargest(10, 'Sales')
    top10_products_per_region = pd.concat([top10_products_per_region, top_products])

print(top10_products_per_region)
# Out:
# Requirement already satisfied: matplotlib in d:\david\learning_platzi\datascientistpython\herramientas_ia\.venv\lib\site-packages (3.10.5)
# Requirement already satisfied: contourpy>=1.0.1 in d:\david\learning_platzi\datascientistpython\herramientas_ia\.venv\lib\site-packages (from matplotlib) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in d:\david\learning_platzi\datascientistpython\herramientas_ia\.venv\lib\site-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in d:\david\learning_platzi\datascientistpython\herramientas_ia\.venv\lib\site-packages (from matplotlib) (4.59.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in d:\david\learning_platzi\datascientistpython\herramientas_ia\.venv\lib\site-packages (from matplotlib) (1.4.9)
# Requirement already satisfied: numpy>=1.23 in d:\david\learning_platzi\datascientistpython\herramientas_ia\.venv\lib\site-packages (from matplotlib) (2.3.2)
# Requirement already satisfied: packaging>=20.0 in d:\david\learning_platzi\datascientistpython\herramientas_ia\.venv\lib\site-packages (from matplotlib) (25.0)
# Requirement already satisfied: pillow>=8 in d:\david\learning_platzi\datascientistpython\herramientas_ia\.venv\lib\site-packages (from matplotlib) (11.3.0)
# Requirement already satisfied: pyparsing>=2.3.1 in d:\david\learning_platzi\datascientistpython\herramientas_ia\.venv\lib\site-packages (from matplotlib) (3.2.3)
# Requirement already satisfied: python-dateutil>=2.7 in d:\david\learning_platzi\datascientistpython\herramientas_ia\.venv\lib\site-packages (from matplotlib) (2.9.0.post0)
# Requirement already satisfied: six>=1.5 in d:\david\learning_platzi\datascientistpython\herramientas_ia\.venv\lib\site-packages (from python-dateutil>=2.7->matplotlib) (1.17.0)
# Note: you may need to restart the kernel to use updated packages.
#        Region                                       Product Name      Sales
# 283   Central              Canon imageCLASS 2200 Advanced Copier  17499.950
# 695   Central          Lexmark MX611dhe Monochrome Laser Printer  14279.916
# 631   Central               Ibico EPK-21 Electric Binding System  11339.940
# 474   Central   GBC Ibimaster 500 Manual ProClick Binding System  10653.720
# 469   Central          GBC DocuBind P400 Electric Binding System   8710.336
# 545   Central       HON 5400 Series Task Chairs for Big and Tall   6939.702
# 441   Central  Fellowes PB500 Electric Punch Plastic Comb Bin...   6100.752
# 279   Central                 Canon PC1060 Personal Laser Copier   4899.930
# 766   Central                       Mitel MiVoice 5330e IP Phone   4179.848
# 732   Central  Martin Yale Chadless Opener Electric Letter Op...   4164.050
# 1592     East              Canon imageCLASS 2200 Advanced Copier  30099.914
# 1297     East   3D Systems Cube Printer, 2nd Generation, Magenta  14299.890
# 2310     East  Riverside Palais Royal Lawyers Bookcase, Royal...  11717.034
# 1803     East         GBC DocuBind TL300 Electric Binding System   8790.502
# 1901     East               Hewlett Packard LaserJet 3310 Copier   8639.856
# 1889     East       HON 5400 Series Task Chairs for Big and Tall   8201.466
# 1401     East                                     Apple iPhone 5   7797.960
# 1409     East                  Ativa V4110MDD Micro-Cut Shredder   7699.890
# 1667     East              DMI Eclipse Executive Suite Bookcases   7214.112
# 1890     East  HP Designjet T520 Inkjet Large Format Printer ...   6999.960
# 2938    South  Cisco TelePresence System EX90 Videoconferenci...  22638.480
# 3139    South  HP Designjet T520 Inkjet Large Format Printer ...  11374.935
# 3078    South         GBC DocuBind TL300 Electric Binding System   8342.007
# 2952    South          Cubify CubeX 3D Printer Triple Head Print   7999.980
# 3058    South  Fellowes PB500 Electric Punch Plastic Comb Bin...   7625.940
# 3463    South                            Samsung Galaxy Mega 6.3   7307.826
# 2930    South  Chromcraft Bull-Nose Wood Oval Conference Tabl...   6611.760
# 3281    South  Martin Yale Chadless Opener Electric Letter Op...   5829.670
# 3552    South                        Tennsco Double-Tier Lockers   5355.476
# 3466    South                           Samsung Galaxy S4 Active   3499.930
# 4045     West              Canon imageCLASS 2200 Advanced Copier  13999.960
# 4377     West        High Speed Automatic Electric Letter Opener  13100.240
# 4343     West      Global Troy Executive Leather Low-Back Tilter  10019.600
# 4240     West  Fellowes PB500 Electric Punch Plastic Comb Bin...   8134.336
# 4358     West         GuestStacker Chair with Chrome Finish Legs   8030.016
# 4705     West                              Okidata MB760 Printer   7834.400
# 4017     West         Bretford Rectangular Conference Table Tops   7710.665
# 4544     West                 Logitech P710e Mobile Speakerphone   7467.210
# 4375     West               Hewlett Packard LaserJet 3310 Copier   6239.896
# 4828     West                           SAFCO Arco Folding Chair   5744.960

# %%
# Crear subgráficos para cada región
fig, axs = plt.subplots(len(grouped['Region'].unique()), 1, figsize=(10, 5*len(grouped['Region'].unique())))

for i, region in enumerate(grouped['Region'].unique()):
    top_products = top10_products_per_region[top10_products_per_region['Region'] == region]
    axs[i].bar(top_products['Product Name'], top_products['Sales'])
    axs[i].set_title('Top 10 productos más vendidos en la región: ' + region)
    axs[i].set_ylabel('Ventas')
    for tick in axs[i].get_xticklabels():
        tick.set_rotation(45)

plt.tight_layout()
plt.show()

# %% [markdown]
# ## Visualizacion

# %%
# %pip install nbformat
# %pip install plotly
import pandas as pd
import plotly.express as px

# Supongamos que tu dataframe se llama df
# Primero necesitamos agregar los datos de ventas tanto para la categoría como para la subcategoría.

# Asegurarse que 'Sales' sea numérico
df['Sales'] = pd.to_numeric(df['Sales'], errors='coerce')

category_sales = df.groupby('Category')['Sales'].sum().reset_index()
sub_category_sales = df.groupby(['Category', 'Sub-Category'])['Sales'].sum().reset_index()

# Ahora vamos a fusionar estos dataframes en uno que tenga la información de las ventas de ambas categorías y subcategorías
merged_df = pd.concat([category_sales, sub_category_sales])

# Filter out non-leaf rows
merged_df = merged_df[merged_df['Sub-Category'].notnull()]

# Crear el diagrama de Sunburst
fig = px.sunburst(merged_df, path=['Category', 'Sub-Category'], values='Sales')
fig.show()
# Out:
# Requirement already satisfied: nbformat in d:\david\learning_platzi\datascientistpython\herramientas_ia\.venv\lib\site-packages (5.10.4)
# Requirement already satisfied: fastjsonschema>=2.15 in d:\david\learning_platzi\datascientistpython\herramientas_ia\.venv\lib\site-packages (from nbformat) (2.21.2)
# Requirement already satisfied: jsonschema>=2.6 in d:\david\learning_platzi\datascientistpython\herramientas_ia\.venv\lib\site-packages (from nbformat) (4.25.1)
# Requirement already satisfied: jupyter-core!=5.0.*,>=4.12 in d:\david\learning_platzi\datascientistpython\herramientas_ia\.venv\lib\site-packages (from nbformat) (5.8.1)
# Requirement already satisfied: traitlets>=5.1 in d:\david\learning_platzi\datascientistpython\herramientas_ia\.venv\lib\site-packages (from nbformat) (5.14.3)
# Requirement already satisfied: attrs>=22.2.0 in d:\david\learning_platzi\datascientistpython\herramientas_ia\.venv\lib\site-packages (from jsonschema>=2.6->nbformat) (25.3.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in d:\david\learning_platzi\datascientistpython\herramientas_ia\.venv\lib\site-packages (from jsonschema>=2.6->nbformat) (2025.4.1)
# Requirement already satisfied: referencing>=0.28.4 in d:\david\learning_platzi\datascientistpython\herramientas_ia\.venv\lib\site-packages (from jsonschema>=2.6->nbformat) (0.36.2)
# Requirement already satisfied: rpds-py>=0.7.1 in d:\david\learning_platzi\datascientistpython\herramientas_ia\.venv\lib\site-packages (from jsonschema>=2.6->nbformat) (0.27.0)
# Requirement already satisfied: platformdirs>=2.5 in d:\david\learning_platzi\datascientistpython\herramientas_ia\.venv\lib\site-packages (from jupyter-core!=5.0.*,>=4.12->nbformat) (4.3.8)
# Requirement already satisfied: pywin32>=300 in d:\david\learning_platzi\datascientistpython\herramientas_ia\.venv\lib\site-packages (from jupyter-core!=5.0.*,>=4.12->nbformat) (311)
# Note: you may need to restart the kernel to use updated packages.
# Requirement already satisfied: plotly in d:\david\learning_platzi\datascientistpython\herramientas_ia\.venv\lib\site-packages (6.3.0)
# Requirement already satisfied: narwhals>=1.15.1 in d:\david\learning_platzi\datascientistpython\herramientas_ia\.venv\lib\site-packages (from plotly) (2.2.0)
# Requirement already satisfied: packaging in d:\david\learning_platzi\datascientistpython\herramientas_ia\.venv\lib\site-packages (from plotly) (25.0)
# Note: you may need to restart the kernel to use updated packages.
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[18], line 23
#      21 # Crear el diagrama de Sunburst
#      22 fig = px.sunburst(merged_df, path=['Category', 'Sub-Category'], values='Sales')
# ---> 23 fig.show()
#
# File d:\david\learning_platzi\dataScientistPython\herramientas_ia\.venv\Lib\site-packages\plotly\basedatatypes.py:3420, in BaseFigure.show(self, *args, **kwargs)
#    3387 """
#    3388 Show a figure using either the default renderer(s) or the renderer(s)
#    3389 specified by the renderer argument
#    (...)   3416 None
#    3417 """
#    3418 import plotly.io as pio
# -> 3420 return pio.show(self, *args, **kwargs)
#
# File d:\david\learning_platzi\dataScientistPython\herramientas_ia\.venv\Lib\site-packages\plotly\io\_renderers.py:415, in show(fig, renderer, validate, **kwargs)
#     410     raise ValueError(
#     411         "Mime type rendering requires ipython but it is not installed"
#     412     )
#     414 if not nbformat or Version(nbformat.__version__) < Version("4.2.0"):
# --> 415     raise ValueError(
#     416         "Mime type rendering requires nbformat>=4.2.0 but it is not installed"
#     417     )
#     419 display_jupyter_version_warnings()
#     421 ipython_display.display(bundle, raw=True)
#
# ValueError: Mime type rendering requires nbformat>=4.2.0 but it is not installed
