# %%
# %pip install tweepy
# %pip install pandas

import os
import tweepy
import pandas as pd

def get_tweets(hashtag):
    # Autenticación
    consumer_key = os.getenv("tw_consumer_key")
    consumer_secret = os.getenv("tw_consumer_secret")
    access_token = os.getenv("tw_access_token")
    access_token_secret = os.getenv("tw_access_token_secret")

    auth = tweepy.OAuthHandler(consumer_key, consumer_secret)
    auth.set_access_token(access_token, access_token_secret)

    api = tweepy.API(auth)
    tweets_data = []
    for tweet in tweepy.Cursor(api.search_tweets, q=hashtag, lang="es").items(50):
        tweet_data = {
            'text': tweet.text,
            'user': tweet.user.screen_name,
            'is_retweet': hasattr(tweet, 'retweeted_status')
        }
        tweets_data.append(tweet_data)
    df = pd.DataFrame(tweets_data, columns=['text', 'user', 'is_retweet'])
    return df
# Out:
# Requirement already satisfied: tweepy in d:\david\learning_platzi\datascientistpython\herramientas_ia\.venv\lib\site-packages (4.16.0)
# Requirement already satisfied: oauthlib<4,>=3.2.0 in d:\david\learning_platzi\datascientistpython\herramientas_ia\.venv\lib\site-packages (from tweepy) (3.3.1)
# Requirement already satisfied: requests<3,>=2.27.0 in d:\david\learning_platzi\datascientistpython\herramientas_ia\.venv\lib\site-packages (from tweepy) (2.32.5)
# Requirement already satisfied: requests-oauthlib<3,>=1.2.0 in d:\david\learning_platzi\datascientistpython\herramientas_ia\.venv\lib\site-packages (from tweepy) (2.0.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in d:\david\learning_platzi\datascientistpython\herramientas_ia\.venv\lib\site-packages (from requests<3,>=2.27.0->tweepy) (3.4.3)
# Requirement already satisfied: idna<4,>=2.5 in d:\david\learning_platzi\datascientistpython\herramientas_ia\.venv\lib\site-packages (from requests<3,>=2.27.0->tweepy) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in d:\david\learning_platzi\datascientistpython\herramientas_ia\.venv\lib\site-packages (from requests<3,>=2.27.0->tweepy) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in d:\david\learning_platzi\datascientistpython\herramientas_ia\.venv\lib\site-packages (from requests<3,>=2.27.0->tweepy) (2025.8.3)
# Note: you may need to restart the kernel to use updated packages.
# Requirement already satisfied: pandas in d:\david\learning_platzi\datascientistpython\herramientas_ia\.venv\lib\site-packages (2.3.2)
# Requirement already satisfied: numpy>=1.26.0 in d:\david\learning_platzi\datascientistpython\herramientas_ia\.venv\lib\site-packages (from pandas) (2.3.2)
# Requirement already satisfied: python-dateutil>=2.8.2 in d:\david\learning_platzi\datascientistpython\herramientas_ia\.venv\lib\site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in d:\david\learning_platzi\datascientistpython\herramientas_ia\.venv\lib\site-packages (from pandas) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in d:\david\learning_platzi\datascientistpython\herramientas_ia\.venv\lib\site-packages (from pandas) (2025.2)
# Requirement already satisfied: six>=1.5 in d:\david\learning_platzi\datascientistpython\herramientas_ia\.venv\lib\site-packages (from python-dateutil>=2.8.2->pandas) (1.17.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
# Set your Twitter API credentials here
os.environ["tw_consumer_key"] = "YOUR_CONSUMER_KEY"
os.environ["tw_consumer_secret"] = "YOUR_CONSUMER_SECRET"
os.environ["tw_access_token"] = "YOUR_ACCESS_TOKEN"
os.environ["tw_access_token_secret"] = "YOUR_ACCESS_TOKEN_SECRET"

df = get_tweets("#inteligenciaartificial")
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[6], line 1
# ----> 1 df = get_tweets("#inteligenciaartificial")
#
# Cell In[5], line 15, in get_tweets(hashtag)
#      12 access_token = os.getenv("tw_access_token")
#      13 access_token_secret = os.getenv("tw_access_token_secret")
# ---> 15 auth = tweepy.OAuthHandler(consumer_key, consumer_secret)
#      16 auth.set_access_token(access_token, access_token_secret)
#      18 api = tweepy.API(auth)
#
# File d:\david\learning_platzi\dataScientistPython\herramientas_ia\.venv\Lib\site-packages\tweepy\auth.py:124, in OAuthHandler.__init__(self, consumer_key, consumer_secret, access_token, access_token_secret, callback)
#     118 def __init__(self, consumer_key, consumer_secret, access_token=None,
#     119              access_token_secret=None, callback=None):
#     120     warnings.warn(
#     121         "OAuthHandler is deprecated; use OAuth1UserHandler instead.",
#     122         DeprecationWarning
#     123     )
# --> 124     super().__init__(consumer_key, consumer_secret, access_token,
#     125                      access_token_secret, callback)
#
# File d:\david\learning_platzi\dataScientistPython\herramientas_ia\.venv\Lib\site-packages\tweepy\auth.py:31, in OAuth1UserHandler.__init__(self, consumer_key, consumer_secret, access_token, access_token_secret, callback)
#      28 def __init__(self, consumer_key, consumer_secret, access_token=None,
#      29              access_token_secret=None, callback=None):
#      30     if not isinstance(consumer_key, (str, bytes)):
# ---> 31         raise TypeError("Consumer key must be string or bytes, not "
#      32                         + type(consumer_key).__name__)
#      33     if not isinstance(consumer_secret, (str, bytes)):
#      34         raise TypeError("Consumer secret must be string or bytes, not "
#      35                         + type(consumer_secret).__name__)
#
# TypeError: Consumer key must be string or bytes, not NoneType

# %%
df.head()
# Out:
#                                                 text        user  is_retweet
# 0  En un mundo donde la #InteligenciaArtificial e...    paisanxs       False
# 1  RT @conectapaciente: Un nuevo software que uti...   marermi13        True
# 2  🚀 ¡Maximiza tu experiencia con #ChatGPT al máx...  IAconNaudy       False
# 3  RT @adigital_org: 🧠En medio de la vorágine de ...    paisanxs        True
# 4  Feliz día a aquellos que se la saben todas per...  asocdepolo       False

# %%
## escribe una funcion para crear una nueva columna con el usuario oroginal del tweet sin tener en cuenta las letras RT, en caso que is_retweet sea True 

def get_original_user(row):
    if row['is_retweet']:
        return row['text'].split(':')[0]
    else:
        return '@'+row['user']

# %%
df['original_user'] = df.apply(get_original_user, axis=1)

# %%
df.head()
# Out:
#                                                 text        user  is_retweet  \
# 0  En un mundo donde la #InteligenciaArtificial e...    paisanxs       False
# 1  RT @conectapaciente: Un nuevo software que uti...   marermi13        True
# 2  🚀 ¡Maximiza tu experiencia con #ChatGPT al máx...  IAconNaudy       False
# 3  RT @adigital_org: 🧠En medio de la vorágine de ...    paisanxs        True
# 4  Feliz día a aquellos que se la saben todas per...  asocdepolo       False
#
#          original_user
# 0            @paisanxs
# 1  RT @conectapaciente
# 2          @IAconNaudy
# 3     RT @adigital_org
# 4          @asocdepolo

# %%
## crea una funcion que elimine los espacios en blanco y las letras RT de la columna original_user en caso que el texto empiece con RT 

def clean_original_user(row):
    if row['original_user'].startswith('RT'):
        return row['original_user'][2:]
    else:
        return row['original_user']

# %%
df['original_user'] = df.apply(clean_original_user, axis=1)

# %%
df.head()
# Out:
#                                                 text        user  is_retweet  \
# 0  En un mundo donde la #InteligenciaArtificial e...    paisanxs       False
# 1  RT @conectapaciente: Un nuevo software que uti...   marermi13        True
# 2  🚀 ¡Maximiza tu experiencia con #ChatGPT al máx...  IAconNaudy       False
# 3  RT @adigital_org: 🧠En medio de la vorágine de ...    paisanxs        True
# 4  Feliz día a aquellos que se la saben todas per...  asocdepolo       False
#
#        original_user
# 0          @paisanxs
# 1   @conectapaciente
# 2        @IAconNaudy
# 3      @adigital_org
# 4        @asocdepolo

# %%
## Crea una fuuncion para eliminar todos los emoji de la columna text

def remove_emoji(text):
    return text.encode('ascii', 'ignore').decode('ascii')

df['text'] = df['text'].apply(remove_emoji)

# %%
df.head()
# Out:
#                                                 text        user  is_retweet  \
# 0  En un mundo donde la #InteligenciaArtificial e...    paisanxs       False
# 1  RT @conectapaciente: Un nuevo software que uti...   marermi13        True
# 2   Maximiza tu experiencia con #ChatGPT al mximo...  IAconNaudy       False
# 3  RT @adigital_org: En medio de la vorgine de in...    paisanxs        True
# 4  Feliz da a aquellos que se la saben todas pero...  asocdepolo       False
#
#        original_user
# 0          @paisanxs
# 1   @conectapaciente
# 2        @IAconNaudy
# 3      @adigital_org
# 4        @asocdepolo
