# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# cargar dataset
df_partidos = pd.read_csv('../data/partidos_cebollitas.csv')
df_partidos.head(6)
# Out:
#   fecha_partido     equipo_local equipo_visitante  goles_local  \
# 0    2023-01-01  Atlético Python    Cebollitas FC            2
# 1    2023-01-08       NumPy City  Atlético Python            1
# 2    2023-01-15    Cebollitas FC      Data United            1
# 3    2023-01-22  Atlético Python      Data United            2
# 4    2023-01-29      Data United    Cebollitas FC            5
# 5    2023-02-05      Data United    Cebollitas FC            3
#
#    goles_visitante  posesion_local (%)  posesion_visitante (%)  \
# 0                0                  54                      46
# 1                5                  60                      40
# 2                0                  55                      45
# 3                3                  57                      43
# 4                3                  52                      48
# 5                3                  60                      40
#
#    tiros_arco_local  tiros_arco_visitante       estadio
# ...

# %%
# general stadistics
df_partidos.describe()
# Out:
#        goles_local  goles_visitante  posesion_local (%)  \
# count    100.00000       100.000000          100.000000
# mean       2.63000         2.540000           50.250000
# std        1.58691         1.788967            6.035878
# min        0.00000         0.000000           40.000000
# 25%        1.00000         1.000000           45.000000
# 50%        3.00000         3.000000           51.000000
# 75%        4.00000         4.000000           55.250000
# max        5.00000         5.000000           60.000000
#
#        posesion_visitante (%)  tiros_arco_local  tiros_arco_visitante
# count              100.000000        100.000000            100.000000
# mean                49.750000          7.580000              7.870000
# std                  6.035878          2.899599              2.966667
# min                 40.000000          3.000000              3.000000
# 25%                 44.750000          5.000000              5.000000
# ...

# %%
# Average goals for Cebollitas as Local and Visitor
goles_local_cebo = df_partidos[df_partidos['equipo_local'] == 'Cebollitas FC']['goles_local'].mean()
goles_visitante_cebo = df_partidos[df_partidos['equipo_visitante'] == 'Cebollitas FC']['goles_visitante'].mean()

print(f"average goals for Cebollitas as Local: {goles_local_cebo}")
print(f"average goals for Cebollitas as Visitor: {goles_visitante_cebo}")
# Out:
# average goals for Cebollitas as Local: 2.230769230769231
# average goals for Cebollitas as Visitor: 2.611111111111111

# %%
# histogram of goals scored by Cebollitas FC (local and visitor)

fig, ax = plt.subplots(1, 2, figsize=(12, 5))

sns.histplot(df_partidos['goles_local'], kde=True, ax=ax[0], bins= 10)
ax[0].set_title('Goals Scored by Cebollitas FC as Local')

sns.histplot(df_partidos['goles_visitante'], kde=True, ax=ax[1], bins= 10, color='orange')
ax[1].set_title('Goals Scored by Cebollitas FC as Visitor')

plt.show()

# %%
# Boxplot of goals scored by Cebollitas FC (local)
sns.boxplot(x=df_partidos['goles_local'])
plt.title('Boxplot of Goals Scored by Cebollitas FC as Local')
plt.show()

# %%
# scatter plot of possession vs goals scored by Cebollitas FC (local)
sns.scatterplot(x=df_partidos['posesion_local (%)'], y=df_partidos['goles_local'], data=df_partidos)
plt.title('Scatter Plot of Possession vs Goals Scored by Cebollitas FC as Local')
plt.show()

# %%
df_partidos
# Out:
#    fecha_partido     equipo_local equipo_visitante  goles_local  \
# 0     2023-01-01  Atlético Python    Cebollitas FC            2
# 1     2023-01-08       NumPy City  Atlético Python            1
# 2     2023-01-15    Cebollitas FC      Data United            1
# 3     2023-01-22  Atlético Python      Data United            2
# 4     2023-01-29      Data United    Cebollitas FC            5
# ..           ...              ...              ...          ...
# 95    2024-10-27      Data United    Cebollitas FC            4
# 96    2024-11-03  Atlético Python      Data United            4
# 97    2024-11-10  Atlético Python      Data United            5
# 98    2024-11-17    Cebollitas FC  Atlético Python            2
# 99    2024-11-24       NumPy City    Cebollitas FC            2
#
#     goles_visitante  posesion_local (%)  posesion_visitante (%)  \
# 0                 0                  54                      46
# 1                 5                  60                      40
# ...

# %%
#heatmap of correlation between key variables
plt.figure(figsize=(10, 8))
sns.heatmap(df_partidos[['goles_local', 'goles_visitante', 'posesion_local (%)', 'posesion_visitante (%)', 'tiros_arco_local', 'tiros_arco_visitante']].corr(), annot=True, cmap='coolwarm', fmt='.2f')
plt.title('Heatmap of Correlation between Key Variables')
plt.show()
