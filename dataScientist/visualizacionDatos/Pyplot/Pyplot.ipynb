# %% [markdown]
# ## On this course we will see how use Pyplot

# %%
import matplotlib.pyplot as plt
import numpy as np

# %% [markdown]
# with the following command we will inidcate that we want some aleatory numebrs and in the second parameter we indicate how many parameters we want

# %%
x = np.linspace(0,5,11)
y = x **2

# %%
print(x)
print(y)
# Out:
# [0.  0.5 1.  1.5 2.  2.5 3.  3.5 4.  4.5 5. ]
# [ 0.    0.25  1.    2.25  4.    6.25  9.   12.25 16.   20.25 25.  ]

# %% [markdown]
# Now with the next command we will find how make  a grafic about the last parameters

# %%
plt.plot(x,y)
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %% [markdown]
# If we want to make a new style we can introduce a new parameter in where we can indicate the color and the form, the first letteer is the color and the second one is the desing

# %%
plt.plot(x,y, 'rx-')
#plt.plot(x,y, 'yo')
