# %% [markdown]
# # Regresion lineal para predecir loss gatos medicos de pacientes

# %%
# !pip install setuptools==57.5.0
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 819.3/819.3 kB 9.6 MB/s eta 0:00:00ta 0:00:01
# ...
#   Attempting uninstall: setuptools
#     Found existing installation: setuptools 68.2.2
#     Uninstalling setuptools-68.2.2:
#       Successfully uninstalled setuptools-68.2.2
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# conda 23.9.0 requires setuptools>=60.0.0, but you have setuptools 57.5.0 which is incompatible.
# ...

# %%
import pandas as pd
import seaborn as sns 
sns.set(style= "whitegrid", context='notebook')

# %% [markdown]
# ## Descargando los datos

# %%
df = pd.read_csv('data/insurance.csv')
df.head()
# Out:
#    age     sex     bmi  children smoker     region      charges
# 0   19  female  27.900         0    yes  southwest  16884.92400
# 1   18    male  33.770         1     no  southeast   1725.55230
# 2   28    male  33.000         3     no  southeast   4449.46200
# 3   33    male  22.705         0     no  northwest  21984.47061
# 4   32    male  28.880         0     no  northwest   3866.85520

# %% [markdown]
# ## Analizando los datos
#
# #### Se empieza viendo como se distribuyen los datos de la variable predictora

# %%
print(df.shape)
df.charges.hist(bins = 40)
# Out:
# (1338, 7)
# <Axes: >

# %%
df[df.charges > 50000]
# Out:
#       age     sex     bmi  children smoker     region      charges
# 34     28    male  36.400         1    yes  southwest  51194.55914
# 543    54  female  47.410         0    yes  southeast  63770.42801
# 577    31  female  38.095         1    yes  northeast  58571.07448
# 819    33  female  35.530         0    yes  northwest  55135.40209
# 1146   60    male  32.800         0    yes  southwest  52590.82939
# 1230   52    male  34.485         3    yes  northwest  60021.39897
# 1300   45    male  30.360         0    yes  southeast  62592.87309

# %%
df = df[df.charges < 50000]

# %%
df.charges.hist(bins = 40)
# Out:
# <Axes: >

# %% [markdown]
# ## Viendo correlaciones
#
# #### despues de analizar y visualizar los datos como lo mencionamos anteriormente, ahora se van a entender a mas profundidad los datos, viendo como se distribuyen y correlacionan

# %%
import matplotlib.pyplot as plt
sns.pairplot(df, height=2.5)
plt.show()

# %%
import n
