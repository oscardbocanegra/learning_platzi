# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn.datasets import make_gaussian_quantiles

# %%
N = 1000 
gaussian_quantiles = make_gaussian_quantiles(n_samples= N, mean=None, cov = 0.1, n_features=2, n_classes=2, shuffle=True, random_state=None)

# %%
X, Y = gaussian_quantiles
X.shape, Y.shape
# Out:
# ((1000, 2), (1000,))

# %%
Y = Y[:, np.newaxis]

# %%
plt.scatter(X[:,0], X[:,1], c=Y.ravel(), s=40, cmap=plt.cm.Spectral)
plt.show()

# %% [markdown]
# # Activation functions

# %%
def sigmoid(x, derivate = False):
    if derivate:
        return np.exp(-x) / ((np.exp(-x) + 1) **2)
    else:
        return 1 / (1 + np.exp(-x))
    
def relu(x, derivate = False):
    if derivate:
        x[X <= 0] = 0
        x[X > 0] = 1
        return x
    else:
        return np.maximum(0, x)

# %% [markdown]
# # Loss function

# %%
def mse(y, y_hat, derivate = False):
    if derivate:
        return (y_hat - y)
    else:
        return np.mean((y_hat - y) ** 2)

# %%
def inizialize_parameters_deep(layers_dim):
    parameters = {}
    L = len(layers_dim)

# %%
np.random.rand(10, 3)
# Out:
# array([[0.70807092, 0.63138004, 0.77028919],
#        [0.97597688, 0.47605938, 0.19585645],
#        [0.23831202, 0.24399242, 0.11596007],
#        [0.77252055, 0.60890226, 0.1764334 ],
#        [0.72976279, 0.64777825, 0.81847141],
#        [0.3029812 , 0.5133589 , 0.34823465],
#        [0.40809062, 0.51574572, 0.41706027],
#        [0.86427896, 0.34870319, 0.48959282],
#        [0.6862046 , 0.00670888, 0.8965093 ],
#        [0.83590684, 0.56821265, 0.73759883]])
