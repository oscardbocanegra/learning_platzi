# %%
/jarvis explicame todo lo que hace este codigo

import torch
import torch.nn as nn

class TextClassifier(nn.Module):
    def __init__(self, vocab_size, embedding_dim, hidden_dim, output_dim):
        super().__init__()

        self.embedding = nn.Embedding(vocab_size, embedding_dim)
        self.rnn = nn.LSTM(embedding_dim, hidden_dim, num_layers=2, batch_first=True)
        self.fc = nn.Linear(hidden_dim, output_dim)

    def forward(self, text):
        embedded = self.embedding(text)
        output, (hidden, cell) = self.rnn(embedded)
        final_hidden = hidden[-1]
        return self.fc(final_hidden)
# Out:
# ```markdown
# # Explanation of the Provided Python Code
#
# This code defines a simple text classification model using PyTorch, a popular deep learning library.
#
# ## Import Statements
#
# - `import torch`: Imports the core functionality of PyTorch.
# - `import torch.nn as nn`: Imports the neural network modules from PyTorch, allowing us to define layers and other building blocks for our model.
#
# ## Class Definition: `TextClassifier`
#
# This class inherits from `nn.Module`, which is the base class for all neural network models in PyTorch. It defines a neural network suitable for text classification tasks.
#
# ### Initialization Method (`__init__`)
#
# - `self.embedding = nn.Embedding(vocab_size, embedding_dim)`: Creates an embedding layer that maps each word (or token) from a vocabulary of size `vocab_size` to a dense vector representation of dimension `embedding_dim`. This is the first layer of the model and converts discrete word indices into continuous vectors.
#
# - `self.rnn = nn.LSTM(embedding_dim, hidden_dim, num_layers=2, batch_first=True)`: Initializes an LSTM (Long Short-Term Memory) layer with:
#   - Input size (`embedding_dim`): The dimensionality of the embedding output.
#   - Hidden size (`hidden_dim`): The number of features in the hidden state of the LSTM.
#   - Number of layers (`num_layers=2`): Two LSTM layers stacked on top of each other, allowing for more complex feature extraction.
#   - `batch_first=True`: Indicates that the input and output tensors are of shape `(batch_size, sequence_length, feature_dim)`.
#
# - `self.fc = nn.Linear(hidden_dim, output_dim)`: Defines a fully connected (linear) layer that takes the final hidden state from the LSTM and maps it to the desired number of classes (`output_dim`), which corresponds to the number of unique labels in the classification task.
#
# ### Forward Method
#
# - `def forward(self, text)`: This method defines how data flows through the network:
#   - `embedded = self.embedding(text)`: Passes the input `text` (which should be a tensor of word indices) through the embedding layer to obtain their dense vector representations.
#
#   - `output, (hidden, cell) = self.rnn(embedded)`: Passes the embedded text through the LSTM. The LSTM returns two outputs:
#     - `output`: The output features at each time step in the sequence.
#     - `(hidden, cell)`: A tuple containing the final hidden state and cell state of the LSTM across all layers.
#
#   - `final_hidden = hidden[-1]`: Selects the last layer's hidden state from the tuple. In a multi-layer setup, this corresponds to the output of the topmost (last) LSTM layer.
#
#   - `return self.fc(final_hidden)`: Passes the final hidden state through the fully connected layer and returns the output as the model's prediction for the class label(s).
#
# ## Summary
#
# The `TextClassifier` class defines a sequential neural network that:
# 1. Embeds input words into dense vectors.
# 2. Processes these vectors through an LSTM to capture dependencies over time (i.e., within sentences).
# 3. Uses the final hidden state from the LSTM to make predictions about the text's classification label(s) via a fully connected layer.
#
# This architecture is suitable for tasks such as sentiment analysis, topic classification, or any other binary/multi-class classification problem involving textual data.
# ```

# %%
vocab_size = 1000
embedding_dim = 100
hidden_dim = 256
output_dim = 2 

model = TextClassifier(vocab_size, embedding_dim, hidden_dim, output_dim)

# %%
model
# Out:
# TextClassifier(
#   (embedding): Embedding(1000, 100)
#   (rnn): LSTM(100, 256, num_layers=2, batch_first=True)
#   (fc): Linear(in_features=256, out_features=2, bias=True)
# )
