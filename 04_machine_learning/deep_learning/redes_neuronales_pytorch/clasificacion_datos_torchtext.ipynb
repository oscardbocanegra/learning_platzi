# %%
# !pip install "portalocker>=2.0.0"
# %pip install torchtext
# !pip install torchtext --upgrade
# Out:
# ...
#   Using cached torchtext-0.18.0-cp311-cp311-manylinux1_x86_64.whl.metadata (7.9 kB)
# ...
# Using cached torchtext-0.18.0-cp311-cp311-manylinux1_x86_64.whl (2.0 MB)
# ...
#
# [notice] A new release of pip is available: 26.0.1 -> 26.1.1
# [notice] To update, run: /home/jovyan/.venv/llm/bin/python -m pip install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.
# ...

# %%
/jarvis soluciona el error

import torch
import torchtext
from torchtext.datasets import DBpedia

# Comprobar la version
torchtext.__version__
# Out:
# ```markdown
# It seems like you are trying to check the version of `torchtext` and might encounter an error if `torchtext` is not properly installed or imported. Here's how you can resolve potential issues:
#
# 1. **Ensure `torchtext` is Installed:**
#    Make sure that `torchtext` is installed in your environment. You can install it using pip if it's not already installed:
#
#    ```bash
#    pip install torchtext
#    ```
#
# 2. **Check for Compatibility:**
#    Ensure that the version of `torchtext` you are using is compatible with the version of `torch`. Sometimes, mismatched versions can cause issues.
#
# 3. **Correct Import and Version Check:**
#    If you have confirmed that `torchtext` is installed, your code should look like this to check its version:
#
#    ```python
#    import torchtext
#
#    # Comprobar la versión
#    print(torchtext.__version__)
#    ```
#
# 4. **Run the Code:**
# ...
